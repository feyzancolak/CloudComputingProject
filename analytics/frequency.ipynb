# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 4
#       2 import numpy as np
#       3 import pandas as pd
# ----> 4 import matplotlib.pyplot as plt
#       5 import seaborn as sns
#
# File ~\AppData\Roaming\Python\Python311\site-packages\matplotlib\__init__.py:981
#     974     return config
#     977 # When constructing the global instances, we need to perform certain updates
#     978 # by explicitly calling the superclass (dict.update, dict.items) to avoid
#     979 # triggering resolution of _auto_backend_sentinel.
#     980 rcParamsDefault = _rc_params_in_file(
# --> 981     cbook._get_data_path("matplotlibrc"),
#     982     # Strip leading comment.
#     983     transform=lambda line: line[1:] if line.startswith("#") else line,
#     984     fail_on_error=True)
#     985 dict.update(rcParamsDefault, rcsetup._hardcoded_defaults)
# ...

# %%
# %pip install --upgrade matplotlib seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install seaborn
# Out:
# ...
#   Obtaining dependency information for seaborn from https://files.pythonhosted.org/packages/83/11/00d3c3dfc25ad54e731d91449895a79e4bf2384dc3ac01809010ba88f6d5/seaborn-0.13.2-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for fonttools>=4.22.0 from https://files.pythonhosted.org/packages/c8/e1/059700c154bd7170d1c37061239836d2e51ff608f47075450f06dd3c292a/fonttools-4.53.1-cp311-cp311-win_amd64.whl.metadata
# ...
#      ---------------------------------------- 0.0/165.9 kB ? eta -:--:--
#      ---------------------------------------- 0.0/165.9 kB ? eta -:--:--
#      -- ------------------------------------- 10.2/165.9 kB ? eta -:--:--
#      ------ ------------------------------ 30.7/165.9 kB 330.3 kB/s eta 0:00:01
#      -------------------- ---------------- 92.2/165.9 kB 655.4 kB/s eta 0:00:01
#      ------------------------------------ 165.9/165.9 kB 997.9 kB/s eta 0:00:00
# ...

# %%
# Frequency of letter in Seagul (small dataset) in English

# %%
seagul_english = {
    'a':0.08798909619266822,
    'b':0.013102570366846254,
    'c':0.01861876534955189,
    'd':0.03776471949698474,
    'e':0.11870748736675625,
    'f':0.022733409625695953,
    'g':0.022129071247637293,
    'h':0.0576050198660169,
    'i':0.07577374599786553,
    'j':8.100705918658626E-4,
    'k':0.011276696969307325,
    'l':0.0417764976662252,
    'm':0.028866801249823198,
    'n':0.07182625914543982,
    'o':0.08087847655295675,
    'p':0.01411837317251932,
    'q':4.50039217703257E-4,
    'r':0.05725784675521724,
    's':0.06502423782643917,
    't':0.08431163287086446,
    'u':0.030371218063288373,
    'v':0.01026089416363426,
    'w':0.019956024739298712,
    'x':9.772280155842152E-4,
    'y':0.02692520348201772,
    'z':4.886140077921076E-4,
}

seagul_english_sorted = dict(sorted(seagul_english.items(), key=lambda item: item[1], reverse=True))


plt.figure(figsize=(12, 6))
sns.barplot(x=list(seagul_english_sorted.keys()), y=list(seagul_english_sorted.values()), palette='coolwarm')
plt.xlabel('Letters')
plt.ylabel('Frequencies')
plt.title('Seagul English input text')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 33
#       1 seagul_english = {
#       2     'a':0.08798909619266822,
#       3     'b':0.013102570366846254,
#    (...)
#      27     'z':4.886140077921076E-4,
#      28 }
#      30 seagul_english_sorted = dict(sorted(seagul_english.items(), key=lambda item: item[1], reverse=True))
# ---> 33 plt.figure(figsize=(12, 6))
#      34 sns.barplot(x=list(seagul_english_sorted.keys()), y=list(seagul_english_sorted.values()), palette='coolwarm')
#      35 plt.xlabel('Letters')
#
# NameError: name 'plt' is not defined

# %%
# Frequency of letter in Seagul (small dataset) in Turkish

# %%
seagul_turkish = {
    'a': 0.11605770243234706,
    'b': 0.026892702958829104,
    'c': 0.008171001368853322,
    'd': 0.04308729072338633,
    'e': 0.08749078656417816,
    'f': 0.003011477308623776,
    'g': 0.01474149731494156,
    'h': 0.009645151100347478,
    'i': 0.08398441613140992,
    'j': 1.0529640939243972E-4,
    'k': 0.04462461830051595,
    'l': 0.05394335053174687,
    'm': 0.03751711066652627,
    'n': 0.07955143729598821,
    'o': 0.03199957881436243,
    'p': 0.008497420237969885,
    'q': 1.0529640939243972E-5,
    'r': 0.07334947878277351,
    's': 0.03229440876066126,
    't': 0.030925555438559547,
    'u': 0.03237864588817521,
    'v': 0.014109718858586922,
    'w': 1.0529640939243972E-5,
    'x': 1.0529640939243972E-5,
    'y': 0.03865431188796462,
    'z': 0.017321259345056333,
    'ç': 0.012319679898915447,
    'ö': 0.008065704959460882,
    'ü': 0.01710013688533221,
    'ğ': 0.010097925660734969,
    'ı': 0.046383068337369694,
    'ş': 0.017647678214172898
}

seagul_turkish_sorted = dict(sorted(seagul_turkish.items(), key=lambda item: item[1], reverse=True))


plt.figure(figsize=(12, 6))
sns.barplot(x=list(seagul_turkish_sorted.keys()), y=list(seagul_turkish_sorted.values()), palette='coolwarm')
plt.xlabel('Letters')
plt.ylabel('Frequencies')
plt.title('Seagul Turkish input text')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
# Frequency of letter in Seagul (small dataset) in Italian

# %%
seagul_italian = {
    'a': 0.11875342692832459,
    'b': 0.009512515461025465,
    'c': 0.04191372429006796,
    'd': 0.03361258814378435,
    'e': 0.11508103490047562,
    'f': 0.008186373895413336,
    'g': 0.017061321296048353,
    'h': 0.011106435612001581,
    'i': 0.10433163740229269,
    'j': 8.160871172997717E-4,
    'k': 0.0035831324993943104,
    'l': 0.048710199813830124,
    'm': 0.02976167705902605,
    'n': 0.08032082424798848,
    'o': 0.10155184065899035,
    'p': 0.028626805911531057,
    'q': 0.004705252285681497,
    'r': 0.06527421802277393,
    's': 0.05384899838057713,
    't': 0.06443262818305855,
    'u': 0.027657702459737577,
    'v': 0.02475039210435714,
    'x': 2.5502722415617867E-5,
    'y': 8.925952845466254E-5,
    'z': 0.006286421075449804
}

seagul_italian_sorted = dict(sorted(seagul_italian.items(), key=lambda item: item[1], reverse=True))


plt.figure(figsize=(12, 6))
sns.barplot(x=list(seagul_italian_sorted.keys()), y=list(seagul_italian_sorted.values()), palette='coolwarm')
plt.xlabel('Letters')
plt.ylabel('Frequencies')
plt.title('Seagul Italian input text')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
#Frequency of letters in Seagul in all languages

# %%
df = pd.DataFrame(
    [
        seagul_english,
        seagul_turkish,
        seagul_italian
    ],
    index=[
        'English', 
        'Turkish', 
        'Italian'
    ]
)
df = df.fillna(0)
df = df.sort_index(axis=1)
df = df.T
df = df.reset_index().melt('index', var_name='Language', value_name='Frequency')

# Plot the data
plt.figure(figsize=(12, 6))
sns.barplot(x='index', y='Frequency', hue='Language', data=df, palette='coolwarm')
plt.xlabel('Letters')
plt.ylabel('Frequencies')
plt.title('All input texts of Seagul')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
# Frequency of letter in Lord of The Ring (medium dataset) in English

# %%
lord_of_the_rings_english = {
    'a': 0.0837096488466786,
    'b': 0.01626144763557237,
    'c': 0.016508748086973394,
    'd': 0.05232735475982331,
    'e': 0.12495021801954517,
    'f': 0.022979850563041415,
    'g': 0.024643467782789398,
    'h': 0.06594841499058082,
    'i': 0.06126125006160312,
    'j': 5.074765097870153E-4,
    'k': 0.008904148209780045,
    'l': 0.04361722862771337,
    'm': 0.0244525536102536,
    'n': 0.0704943922291716,
    'o': 0.07876719171024024,
    'p': 0.012926665426464522,
    'q': 5.41219479816598E-4,
    'r': 0.060971326911217365,
    's': 0.061003737921903674,
    't': 0.08890073839386127,
    'u': 0.02595145185788349,
    'v': 0.008042814501130167,
    'w': 0.026591680315550047,
    'x': 5.567590054881165E-4,
    'y': 0.018736672081821375,
    'z': 4.4354246130991096E-4
}

lord_of_the_rings_english_sorted = dict(sorted(lord_of_the_rings_english.items(), key=lambda item: item[1], reverse=True))


plt.figure(figsize=(12, 6))
sns.barplot(x=list(lord_of_the_rings_english_sorted.keys()), y=list(lord_of_the_rings_english_sorted.values()), palette='coolwarm')
plt.xlabel('Letters')
plt.ylabel('Frequencies')
plt.title('Lord of the Rings English input text')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
# Frequency of letter in Lord of The Ring (medium dataset) in Turkish

# %%
lord_of_the_rings_turkish = {
    'a': 0.11682756557473961,
    'b': 0.02793308349067927,
    'c': 0.00818004793826068,
    'd': 0.05490372936737977,
    'e': 0.09109478734114629,
    'f': 0.005942570823585051,
    'g': 0.016168414490396226,
    'h': 0.012233123976654282,
    'i': 0.08137904904535503,
    'j': 5.508600582568101E-5,
    'k': 0.04550641505648331,
    'l': 0.061040668699325354,
    'm': 0.032330559028909855,
    'n': 0.07200502312716538,
    'o': 0.02973300753469075,
    'p': 0.007984783722488347,
    'q': 2.5527661236291197E-5,
    'r': 0.07447986270596792,
    's': 0.026139877252256288,
    't': 0.029299933001085597,
    'u': 0.03296740699869943,
    'v': 0.010284512502284054,
    'w': 1.5585308965314625E-4,
    'x': 9.852781529796602E-6,
    'y': 0.03424065508457269,
    'z': 0.015180897068887065,
    'ç': 0.011440870770917455,
    'ö': 0.008121826956493699,
    'ü': 0.02025239243449692,
    'ğ': 0.010489629499586184,
    'ı': 0.046585742487701934,
    'ş': 0.017007244481546637
}

lord_of_the_rings_turkish_sorted = dict(sorted(lord_of_the_rings_turkish.items(), key=lambda item: item[1], reverse=True))


plt.figure(figsize=(12, 6))
sns.barplot(x=list(lord_of_the_rings_turkish_sorted.keys()), y=list(lord_of_the_rings_turkish_sorted.values()), palette='coolwarm')
plt.xlabel('Letters')
plt.ylabel('Frequencies')
plt.title('Lord of the Rings Turkish input text')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
# Frequency of letter in Lord of The Ring (medium dataset) in Italian

# %%
lord_of_the_rings_italian = {
    'a': 0.11055456157106971,
    'b': 0.011313569578187146,
    'c': 0.04153242424638895,
    'd': 0.0403745322639732,
    'e': 0.11520739022922336,
    'f': 0.011771901821226711,
    'g': 0.021048121205777686,
    'h': 0.011642702009629474,
    'i': 0.10171500484090433,
    'j': 6.1329024492359225E-6,
    'k': 2.367300345405066E-4,
    'l': 0.061124594410718026,
    'm': 0.02879193269834624,
    'n': 0.0725861713680134,
    'o': 0.10098805147058823,
    'p': 0.0263498109430605,
    'q': 0.00456696802386435,
    'r': 0.07072013358279254,
    's': 0.05411305147058824,
    't': 0.05626692681075989,
    'u': 0.03239767047833368,
    'v': 0.021265225952480635,
    'w': 1.5536686204731002E-4,
    'x': 9.812643918777476E-6,
    'y': 4.4197783650826877E-4,
    'z': 0.004819234744609588
}

lord_of_the_rings_italian_sorted = dict(sorted(lord_of_the_rings_italian.items(), key=lambda item: item[1], reverse=True))


plt.figure(figsize=(12, 6))
sns.barplot(x=list(lord_of_the_rings_italian_sorted.keys()), y=list(lord_of_the_rings_italian_sorted.values()), palette='coolwarm')
plt.xlabel('Letters')
plt.ylabel('Frequencies')
plt.title('Lord of the Rings Italian input text')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
# Frequency of letter in Lord of the Rings in All Languages

# %%
df = pd.DataFrame(
    [
        lord_of_the_rings_english,
        lord_of_the_rings_turkish,
        lord_of_the_rings_italian
    ],
    index=[
        'English', 
        'Turkish', 
        'Italian'
    ]
)
df = df.fillna(0)
df = df.sort_index(axis=1)
df = df.T
df = df.reset_index().melt('index', var_name='Language', value_name='Frequency')

# Plot the data
plt.figure(figsize=(12, 6))
sns.barplot(x='index', y='Frequency', hue='Language', data=df, palette='coolwarm')
plt.xlabel('Letters')
plt.ylabel('Frequencies')
plt.title('All input texts of Lord of the Rings')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
# Frequency of letter just in English in both Seagul and Lord of the Rings

# %%
df = pd.DataFrame(
    [
        seagul_english,
        lord_of_the_rings_english
    ],
    index=[
        'Seagul', 
        'Lord of the Rings' 
    ]
)
df = df.fillna(0)
df = df.sort_index(axis=1)
df = df.T
df = df.reset_index().melt('index', var_name='Dataset', value_name='Frequency')

# Plot the data
plt.figure(figsize=(12, 6))
sns.barplot(x='index', y='Frequency', hue='Dataset', data=df, palette='coolwarm')
plt.xlabel('Letters')
plt.ylabel('Frequencies')
plt.title('All input texts in English')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
# Frequency of letter just in Turkish in both Seagul and Lord of the Rings

# %%
df = pd.DataFrame(
    [
        seagul_turkish,
        lord_of_the_rings_turkish
    ],
    index=[
        'Seagul', 
        'Lord of the Rings' 
    ]
)
df = df.fillna(0)
df = df.sort_index(axis=1)
df = df.T
df = df.reset_index().melt('index', var_name='Dataset', value_name='Frequency')

# Plot the data
plt.figure(figsize=(12, 6))
sns.barplot(x='index', y='Frequency', hue='Dataset', data=df, palette='coolwarm')
plt.xlabel('Letters')
plt.ylabel('Frequencies')
plt.title('All input texts in Turkish')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
# Frequency of letter just in Italian in both Seagul and Lord of the Rings

# %%
df = pd.DataFrame(
    [
        seagul_italian,
        lord_of_the_rings_italian
    ],
    index=[
        'Seagul', 
        'Lord of the Rings' 
    ]
)
df = df.fillna(0)
df = df.sort_index(axis=1)
df = df.T
df = df.reset_index().melt('index', var_name='Dataset', value_name='Frequency')

# Plot the data
plt.figure(figsize=(12, 6))
sns.barplot(x='index', y='Frequency', hue='Dataset', data=df, palette='coolwarm')
plt.xlabel('Letters')
plt.ylabel('Frequencies')
plt.title('All input texts in Italian')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
